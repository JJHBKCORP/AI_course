# %% [markdown]
# <a href="https://colab.research.google.com/github/jjhbk/AI_course/blob/main/DeepQ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the dataset
dataset = pd.read_csv('kc_house_data.csv')

# Getting separately the features and the targets
X = dataset.iloc[:, 3:].values
X = X[:, np.r_[0:13,14:18]]
y = dataset.iloc[:, 2].values

# Splitting the dataset into a training set and a test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Scaling the features
xscaler = MinMaxScaler(feature_range = (0,1))
X_train = xscaler.fit_transform(X_train)
X_test = xscaler.transform(X_test)

# Scaling the target
yscaler = MinMaxScaler(feature_range = (0,1))
y_train = yscaler.fit_transform(y_train.reshape(-1,1))
y_test = yscaler.transform(y_test.reshape(-1,1))

# Building the Artificial Neural Network
model = Sequential()
model.add(Dense(units = 64, kernel_initializer = 'uniform', activation = 'relu', input_dim = 17))
model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'relu'))
model.compile(optimizer = Adam(lr = 0.001), loss = 'mse', metrics = ['mean_absolute_error'])

# Training the Artificial Neural Network
model.fit(X_train, y_train, batch_size = 32, epochs = 100, validation_data = (X_test, y_test))

# Making predictions on the test set while reversing the scaling
y_test = yscaler.inverse_transform(y_test)
prediction = yscaler.inverse_transform(model.predict(X_test))

# Computing the error rate
error = abs(prediction - y_test)/y_test
print(np.mean(error))
# Out:
# Epoch 1/100
# 541/541 [==============================] - 2s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 2/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 3/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 4/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 5/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0606 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 6/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0063 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 7/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 8/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 9/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0064 - mean_absolute_error: 0.0619 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 10/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0064 - mean_absolute_error: 0.0622 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 11/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0619 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 12/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0616 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 13/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0616 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 14/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 15/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0058 - mean_absolute_error: 0.0606 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 16/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 17/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 18/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 19/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0611 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 20/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 21/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0611 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 22/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 23/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0616 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 24/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 25/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 26/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 27/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0614 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 28/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0623 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 29/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 30/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 31/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 32/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 33/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 34/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 35/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0614 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 36/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 37/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 38/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 39/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0612 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 40/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 41/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0610 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 42/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 43/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 44/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 45/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 46/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 47/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 48/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 49/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 50/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 51/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 52/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0612 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 53/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 54/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 55/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 56/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 57/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 58/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 59/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 60/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 61/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0616 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 62/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0608 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 63/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0616 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 64/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0616 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 65/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0612 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 66/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0611 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 67/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 68/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 69/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0614 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 70/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 71/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 72/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0611 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 73/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0059 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 74/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 75/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0609 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 76/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0614 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 77/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0614 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 78/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0614 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 79/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 80/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0621 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 81/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0062 - mean_absolute_error: 0.0613 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 82/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 83/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 84/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0612 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 85/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0065 - mean_absolute_error: 0.0620 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 86/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0611 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 87/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0607 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 88/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 89/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0611 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 90/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0063 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 91/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0062 - mean_absolute_error: 0.0617 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 92/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0604 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 93/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0060 - mean_absolute_error: 0.0609 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 94/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0067 - mean_absolute_error: 0.0625 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 95/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 96/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0060 - mean_absolute_error: 0.0610 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 97/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 98/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 99/100
# 541/541 [==============================] - 1s 1ms/step - loss: 0.0061 - mean_absolute_error: 0.0615 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# Epoch 100/100
# 541/541 [==============================] - 1s 2ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0056 - val_mean_absolute_error: 0.0596
# 0.8142614273107801
